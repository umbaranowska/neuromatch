# %%
# this notebook is for analysing data after downloading it from google drive to your computer

# %%
import os

import pandas as pd
import numpy as np
from icecream import ic
from tqdm import tqdm

from event_triggered_response import *

import seaborn as sns
sns.set_theme(style="darkgrid")
sns.set_palette('colorblind')

# %%
all_data_folders = os.listdir('data')

# %%
multiscope_experiment_table = pd.read_csv('multiscope_experiment_table_filtered.csv', index_col='ophys_experiment_id').reset_index().drop(columns = ['Unnamed: 0'])
multiscope_experiment_table.head()
# Out:
#    ophys_experiment_id  ophys_session_id  ophys_container_id  mouse_id  \
# 0            951980473         951410079          1018028345    457841
# 1            953659743         952430817          1018028345    457841
# 2            958527471         954954402          1018028345    457841
# 3            956941844         955775716          1018028345    457841
# 4            957759564         957020350          1018028345    457841
#
#        cre_line              session_type  imaging_depth experience_level
# 0  Sst-IRES-Cre          OPHYS_1_images_A            225         Familiar
# 1  Sst-IRES-Cre  OPHYS_2_images_A_passive            225         Familiar
# 2  Sst-IRES-Cre          OPHYS_3_images_A            225         Familiar
# 3  Sst-IRES-Cre          OPHYS_3_images_A            225         Familiar
# 4  Sst-IRES-Cre          OPHYS_4_images_B            225          Novel 1

# %%
if not os.path.exists('cell_etr_data'):
    os.mkdir('cell_etr_data')

for folder in tqdm(all_data_folders):
    try:
        neural_data = pd.read_csv(f'data/{folder}/neural_data.csv').drop(columns = ['Unnamed: 0'])
        stimulus_presentations = pd.read_csv(f'data/{folder}/stimulus_presentations.csv').drop(columns = ['Unnamed: 0'])
        for id in tqdm(np.random.choice(neural_data['ophys_experiment_id'].unique().tolist(), size = 2, replace = False)):
            n = neural_data[neural_data['ophys_experiment_id'] == id]
            s = stimulus_presentations[stimulus_presentations['ophys_experiment_id'] == id]
            for cell in tqdm(np.random.choice(n['cell_specimen_id'].unique().tolist(), size = 5, replace = False)):
                etr = event_triggered_response(data=n[n['cell_specimen_id'] == cell],
                                               t='timestamps',
                                               y='dff',
                                               event_times=s[s['omitted'] == False]['start_time'],
                                               t_before=3,
                                               t_after=3,
                                               output_sampling_rate=50)
                etr.insert(0, 'ophys_experiment_id', [id for i in range(etr.shape[0])])
                etr.insert(0, 'cell_specimen_id', [cell for i in range(etr.shape[0])])
                etr.to_csv(f'cell_etr_data/{id}_{cell}.csv')
    except:
        print(folder)
# Out:
#   0%|          | 0/14 [00:00<?, ?it/s]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.17s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.21s/it]
#
#  60%|██████    | 3/5 [00:32<00:22, 11.19s/it]
#
#  80%|████████  | 4/5 [00:43<00:11, 11.04s/it]
#
# 100%|██████████| 5/5 [00:53<00:00, 10.75s/it]
#
#  50%|█████     | 1/2 [00:53<00:53, 53.85s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.14s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.14s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.18s/it]
#
#  80%|████████  | 4/5 [00:40<00:10, 10.17s/it]
#
# 100%|██████████| 5/5 [00:51<00:00, 10.21s/it]
#
# 100%|██████████| 2/2 [01:44<00:00, 52.48s/it]
#   7%|▋         | 1/14 [01:55<25:01, 115.53s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.12s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.16s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.19s/it]
#
#  80%|████████  | 4/5 [00:40<00:10, 10.14s/it]
#
# 100%|██████████| 5/5 [00:50<00:00, 10.14s/it]
#
#  50%|█████     | 1/2 [00:50<00:50, 50.75s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.11s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.28s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.26s/it]
#
#  80%|████████  | 4/5 [00:40<00:10, 10.21s/it]
#
# 100%|██████████| 5/5 [00:51<00:00, 10.21s/it]
#
# 100%|██████████| 2/2 [01:41<00:00, 50.92s/it]
#  14%|█▍        | 2/14 [03:43<22:14, 111.25s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.10s/it]
#
#  40%|████      | 2/5 [00:20<00:31, 10.47s/it]
#
#  60%|██████    | 3/5 [00:32<00:21, 10.99s/it]
#
#  80%|████████  | 4/5 [00:44<00:11, 11.56s/it]
#
# 100%|██████████| 5/5 [00:57<00:00, 11.50s/it]
#
#  50%|█████     | 1/2 [00:57<00:57, 57.57s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:42, 10.72s/it]
#
#  40%|████      | 2/5 [00:21<00:32, 10.93s/it]
#
#  60%|██████    | 3/5 [00:35<00:24, 12.14s/it]
#
#  80%|████████  | 4/5 [00:46<00:11, 11.73s/it]
#
# 100%|██████████| 5/5 [00:57<00:00, 11.41s/it]
#
# 100%|██████████| 2/2 [01:54<00:00, 57.33s/it]
#  21%|██▏       | 3/14 [05:47<21:26, 116.96s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.23s/it]
#
#  40%|████      | 2/5 [00:21<00:31, 10.63s/it]
#
#  60%|██████    | 3/5 [00:31<00:21, 10.68s/it]
#
#  80%|████████  | 4/5 [00:43<00:10, 10.87s/it]
#
# 100%|██████████| 5/5 [00:54<00:00, 10.90s/it]
#
#  50%|█████     | 1/2 [00:54<00:54, 54.62s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:43, 10.81s/it]
#
#  40%|████      | 2/5 [00:21<00:32, 10.82s/it]
#
#  60%|██████    | 3/5 [00:33<00:22, 11.27s/it]
#
#  80%|████████  | 4/5 [00:47<00:12, 12.21s/it]
#
# 100%|██████████| 5/5 [00:58<00:00, 11.71s/it]
#
# 100%|██████████| 2/2 [01:53<00:00, 56.62s/it]
#  29%|██▊       | 4/14 [07:47<19:42, 118.29s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:13<00:55, 13.76s/it]
#
#  40%|████      | 2/5 [00:27<00:42, 14.02s/it]
#
#  60%|██████    | 3/5 [00:39<00:25, 12.94s/it]
#
#  80%|████████  | 4/5 [00:51<00:12, 12.43s/it]
#
# 100%|██████████| 5/5 [01:01<00:00, 12.33s/it]
#
#  50%|█████     | 1/2 [01:01<01:01, 61.70s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:13<00:52, 13.25s/it]
#
#  40%|████      | 2/5 [00:24<00:36, 12.06s/it]
#
#  60%|██████    | 3/5 [00:35<00:22, 11.45s/it]
#
#  80%|████████  | 4/5 [00:45<00:10, 10.98s/it]
#
# 100%|██████████| 5/5 [00:55<00:00, 11.18s/it]
#
# 100%|██████████| 2/2 [01:57<00:00, 58.82s/it]
#  36%|███▌      | 5/14 [09:51<18:01, 120.12s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:41, 10.32s/it]
#
#  40%|████      | 2/5 [00:20<00:31, 10.35s/it]
#
#  60%|██████    | 3/5 [00:31<00:20, 10.50s/it]
#
#  80%|████████  | 4/5 [00:41<00:10, 10.50s/it]
#
# 100%|██████████| 5/5 [00:52<00:00, 10.45s/it]
#
#  50%|█████     | 1/2 [00:52<00:52, 52.33s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:42, 10.71s/it]
#
#  40%|████      | 2/5 [00:21<00:32, 10.85s/it]
#
#  60%|██████    | 3/5 [00:35<00:24, 12.11s/it]
#
#  80%|████████  | 4/5 [00:46<00:11, 11.89s/it]
#
# 100%|██████████| 5/5 [00:58<00:00, 11.65s/it]
#
# 100%|██████████| 2/2 [01:50<00:00, 55.33s/it]
#  43%|████▎     | 6/14 [11:53<16:07, 120.98s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:11<00:45, 11.34s/it]
#
#  40%|████      | 2/5 [00:22<00:33, 11.10s/it]
#
#  60%|██████    | 3/5 [00:32<00:21, 10.91s/it]
#
#  80%|████████  | 4/5 [00:45<00:11, 11.55s/it]
#
# 100%|██████████| 5/5 [00:56<00:00, 11.22s/it]
#
#  50%|█████     | 1/2 [00:56<00:56, 56.29s/it]
#  50%|█████     | 7/14 [13:03<12:08, 104.06s/it]
# Vip-IRES-Cre_Familiar_OPHYS_1_images_A
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:11<00:45, 11.39s/it]
#
#  40%|████      | 2/5 [00:21<00:32, 10.91s/it]
#
#  60%|██████    | 3/5 [00:35<00:24, 12.15s/it]
#
#  80%|████████  | 4/5 [00:47<00:12, 12.07s/it]
#
# 100%|██████████| 5/5 [00:58<00:00, 11.60s/it]
#
#  50%|█████     | 1/2 [00:58<00:58, 58.08s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:43, 10.76s/it]
#
#  40%|████      | 2/5 [00:21<00:33, 11.02s/it]
#
#  60%|██████    | 3/5 [00:32<00:21, 10.71s/it]
#
#  80%|████████  | 4/5 [00:43<00:10, 10.83s/it]
#
# 100%|██████████| 5/5 [00:53<00:00, 10.78s/it]
#
# 100%|██████████| 2/2 [01:52<00:00, 56.02s/it]
#  64%|██████▍   | 9/14 [15:05<06:18, 75.64s/it]
# Vip-IRES-Cre_Familiar_OPHYS_2_images_B_passive
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:42, 10.57s/it]
#
#  40%|████      | 2/5 [00:20<00:31, 10.35s/it]
#
#  60%|██████    | 3/5 [00:33<00:23, 11.60s/it]
#
#  80%|████████  | 4/5 [00:45<00:11, 11.70s/it]
#
# 100%|██████████| 5/5 [00:56<00:00, 11.23s/it]
#
#  50%|█████     | 1/2 [00:56<00:56, 56.30s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.09s/it]
#
#  40%|████      | 2/5 [00:20<00:31, 10.38s/it]
#
#  60%|██████    | 3/5 [00:33<00:22, 11.32s/it]
#
#  80%|████████  | 4/5 [00:45<00:11, 11.71s/it]
#
# 100%|██████████| 5/5 [00:56<00:00, 11.25s/it]
#
# 100%|██████████| 2/2 [01:52<00:00, 56.31s/it]
#  71%|███████▏  | 10/14 [17:08<06:00, 90.17s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.19s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.18s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.21s/it]
#
#  80%|████████  | 4/5 [00:40<00:10, 10.16s/it]
#
# 100%|██████████| 5/5 [00:50<00:00, 10.16s/it]
#
#  50%|█████     | 1/2 [00:50<00:50, 50.90s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:41, 10.26s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.20s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.20s/it]
#
#  80%|████████  | 4/5 [00:40<00:10, 10.15s/it]
#
# 100%|██████████| 5/5 [00:50<00:00, 10.17s/it]
#
# 100%|██████████| 2/2 [01:41<00:00, 50.92s/it]
#  79%|███████▊  | 11/14 [18:58<04:49, 96.40s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:41, 10.39s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.21s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.28s/it]
#
#  80%|████████  | 4/5 [00:43<00:11, 11.33s/it]
#
# 100%|██████████| 5/5 [00:54<00:00, 10.91s/it]
#
#  50%|█████     | 1/2 [00:54<00:54, 54.63s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:12<00:51, 12.96s/it]
#
#  40%|████      | 2/5 [00:23<00:34, 11.64s/it]
#
#  60%|██████    | 3/5 [00:33<00:21, 10.95s/it]
#
#  80%|████████  | 4/5 [00:43<00:10, 10.61s/it]
#
# 100%|██████████| 5/5 [00:54<00:00, 10.86s/it]
#
# 100%|██████████| 2/2 [01:49<00:00, 54.51s/it]
#  86%|████████▌ | 12/14 [20:56<03:25, 102.78s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:41, 10.27s/it]
#
#  40%|████      | 2/5 [00:20<00:31, 10.34s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.23s/it]
#
#  80%|████████  | 4/5 [00:43<00:11, 11.41s/it]
#
# 100%|██████████| 5/5 [00:54<00:00, 10.97s/it]
#
#  50%|█████     | 1/2 [00:54<00:54, 54.98s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.09s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.16s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.12s/it]
#
#  80%|████████  | 4/5 [00:43<00:11, 11.18s/it]
#
# 100%|██████████| 5/5 [00:54<00:00, 10.82s/it]
#
# 100%|██████████| 2/2 [01:49<00:00, 54.58s/it]
#  93%|█████████▎| 13/14 [22:55<01:47, 107.66s/it]
#   0%|          | 0/2 [00:00<?, ?it/s]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:41, 10.42s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.20s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.15s/it]
#
#  80%|████████  | 4/5 [00:40<00:10, 10.16s/it]
#
# 100%|██████████| 5/5 [00:50<00:00, 10.15s/it]
#
#  50%|█████     | 1/2 [00:50<00:50, 50.84s/it]
#
#   0%|          | 0/5 [00:00<?, ?it/s]
#
#  20%|██        | 1/5 [00:10<00:40, 10.07s/it]
#
#  40%|████      | 2/5 [00:20<00:30, 10.06s/it]
#
#  60%|██████    | 3/5 [00:30<00:20, 10.05s/it]
#
#  80%|████████  | 4/5 [00:40<00:10, 10.11s/it]
#
# 100%|██████████| 5/5 [00:50<00:00, 10.18s/it]
#
# 100%|██████████| 2/2 [01:41<00:00, 50.94s/it]
# 100%|██████████| 14/14 [24:46<00:00, 106.21s/it]
